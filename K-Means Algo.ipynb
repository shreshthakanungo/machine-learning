# %% [markdown]
# # Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Get the Dataset

# %%
dataset = pd.read_csv("College.csv")

# %%
df = pd.DataFrame(dataset)

# %%
df.head(25)
# Out:
#                                College Name Private   Apps  Accept  Enroll  \
# 0              Abilene Christian University     Yes   1660    1232     721
# 1                        Adelphi University     Yes   2186    1924     512
# 2                            Adrian College     Yes   1428    1097     336
# 3                       Agnes Scott College     Yes    417     349     137
# 4                 Alaska Pacific University     Yes    193     146      55
# 5                         Albertson College     Yes    587     479     158
# 6                   Albertus Magnus College     Yes    353     340     103
# 7                            Albion College     Yes   1899    1720     489
# 8                          Albright College     Yes   1038     839     227
# 9                 Alderson-Broaddus College     Yes    582     498     172
# 10                        Alfred University     Yes   1732    1425     472
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 19 columns):
# College Name    777 non-null object
# Private         777 non-null object
# Apps            777 non-null int64
# Accept          777 non-null int64
# Enroll          777 non-null int64
# Top10perc       777 non-null int64
# Top25perc       777 non-null int64
# F.Undergrad     777 non-null int64
# P.Undergrad     777 non-null int64
# Outstate        777 non-null int64
# Room.Board      777 non-null int64
# Books           777 non-null int64
# Personal        777 non-null int64
# PhD             777 non-null int64
# Terminal        777 non-null int64
# S.F.Ratio       777 non-null float64
# perc.alumni     777 non-null int64
# Expend          777 non-null int64
# Grad.Rate       777 non-null int64
# dtypes: float64(1), int64(16), object(2)
# memory usage: 115.5+ KB

# %%
df.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder() 
df['Private']= label_encoder.fit_transform(df['Private'])

# %%
df.head(25)
# Out:
#                                College Name  Private   Apps  Accept  Enroll  \
# 0              Abilene Christian University        1   1660    1232     721
# 1                        Adelphi University        1   2186    1924     512
# 2                            Adrian College        1   1428    1097     336
# 3                       Agnes Scott College        1    417     349     137
# 4                 Alaska Pacific University        1    193     146      55
# 5                         Albertson College        1    587     479     158
# 6                   Albertus Magnus College        1    353     340     103
# 7                            Albion College        1   1899    1720     489
# 8                          Albright College        1   1038     839     227
# 9                 Alderson-Broaddus College        1    582     498     172
# 10                        Alfred University        1   1732    1425     472
# ...

# %% [markdown]
# ## Create a scatter plot

# %%
sns.set_style('whitegrid')
sns.lmplot('Room.Board','Grad.Rate',data=df, hue='Private', palette='coolwarm',size=6, aspect=1, fit_reg=False)
# Out:
# /Users/Ashwin/anaconda3/lib/python3.7/site-packages/seaborn/regression.py:574: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Creating a scatter plot for F-undergrad and outstate

# %%
sns.set_style('whitegrid')
sns.lmplot('Outstate','F.Undergrad', data=df, hue='Private',palette='coolwarm',size=6, aspect=1, fit_reg=False)

# %% [markdown]
# ## Create a histogram showoing outstate based on private

# %%
sns.set_style('darkgrid')
g = sns.FacetGrid(df, hue='Private',palette='coolwarm',height=6, aspect=2)
g = g.map(plt.hist, 'Outstate', bins=20, alpha=0.7)

# %%
sns.set_style('darkgrid')
g = sns.FacetGrid(df,hue="Private",palette='coolwarm',height=6,aspect=2)
g = g.map(plt.hist,'Grad.Rate',bins=20,alpha=0.7)

# %%
df[df['Grad.Rate']>100]
# Out:
#          College Name  Private  Apps  Accept  Enroll  Top10perc  Top25perc  \
# 95  Cazenovia College        1  3847    3433     527          9         35
#
#     F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  \
# 95         1010           12      9384        4840    600       500   22
#
#     Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 95        47       14.3           20    7697        118

# %%
#df['Grad.Rate']['Cazenovia College'] == 100
#df['Cazenovia College'] = np.where(df['Grad.Rate'] == 118, 100,100)
df.loc[df['Grad.Rate']==118, ['Grad.Rate']]= 100

# %%
df[df['Grad.Rate'] > 100]
# Out:
# Empty DataFrame
# Columns: [College Name, Private, Apps, Accept, Enroll, Top10perc, Top25perc, F.Undergrad, P.Undergrad, Outstate, Room.Board, Books, Personal, PhD, Terminal, S.F.Ratio, perc.alumni, Expend, Grad.Rate]
# Index: []

# %%
sns.set_style('darkgrid')
g = sns.FacetGrid(df, hue='Private', palette='coolwarm', size=6, aspect=2)
g = g.map(plt.hist,'Grad.Rate', bins=20, alpha=0.7)
# Out:
# /Users/Ashwin/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## K-Means Cluster creation

# %% [markdown]
# ### Import K-means from sklearn

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# #### Creating an Instance of KMeans with 2 Clusters

# %%
kmeans = KMeans(n_clusters=2)

# %% [markdown]
# #### Fit the model to all the data except for the Private level

# %%
#df = df.drop('Private', axis=1)

# %%
df = df.drop('College Name', axis=1)

# %%
kmeans.fit(df)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[7.93721973e-01, 1.81323468e+03, 1.28716592e+03, 4.91044843e+02,
#         2.53094170e+01, 5.34708520e+01, 2.18854858e+03, 5.95458894e+02,
#         1.03957085e+04, 4.31136472e+03, 5.41982063e+02, 1.28033632e+03,
#         7.04424514e+01, 7.78251121e+01, 1.40997010e+01, 2.31748879e+01,
#         8.93204634e+03, 6.50926756e+01],
#        [3.14814815e-01, 1.03631389e+04, 6.55089815e+03, 2.56972222e+03,
#         4.14907407e+01, 7.02037037e+01, 1.30619352e+04, 2.46486111e+03,
#         1.07191759e+04, 4.64347222e+03, 5.95212963e+02, 1.71420370e+03,
#         8.63981481e+01, 9.13333333e+01, 1.40277778e+01, 2.00740741e+01,
#         1.41705000e+04, 6.75925926e+01]])

# %%
def converter(cluster):
    if cluster=='Yes':
        return 1
    else:
        return 0

# %%
df['Cluster'] = df['Private'].apply(converter)

# %%
df.head()
# Out:
#    Private  Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0        1  1660    1232     721         23         52         2885
# 1        1  2186    1924     512         16         29         2683
# 2        1  1428    1097     336         22         50         1036
# 3        1   417     349     137         60         89          510
# 4        1   193     146      55         16         44          249
#
#    P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# 0          537      7440        3300    450      2200   70        78
# 1         1227     12280        6450    750      1500   29        30
# 2           99     11250        3750    400      1165   53        66
# 3           63     12960        5450    450       875   92        97
# 4          869      7560        4120    800      1500   76        72
#
#    S.F.Ratio  perc.alumni  Expend  Grad.Rate  Cluster
# 0       18.1           12    7041         60        0
# ...

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(confusion_matrix(df['Cluster'],kmeans.labels_))
print(classification_report(df['Cluster'],kmeans.labels_))
# Out:
# [[669 108]
#  [  0   0]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.86      0.93       777
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.86       777
#    macro avg       0.50      0.43      0.46       777
# weighted avg       1.00      0.86      0.93       777
# /Users/Ashwin/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1268: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
